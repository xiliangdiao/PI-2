# %%
import netCDF4 as nc
import matplotlib.pyplot as plt
from matplotlib.colors import from_levels_and_colors
import numpy as np
from matplotlib import animation
from matplotlib.colors import BoundaryNorm
import matplotlib.colors as cols
import matplotlib as mpl
from mpl_toolkits.basemap import Basemap
from matplotlib import ticker, cm
import seaborn as sns

# %%
# 读取文件
final = np.loadtxt(fname="/scratch/user/xiliangdiao/firstpaper/ACCeast1.out",  delimiter=",")
fina2 = np.loadtxt(fname="/scratch/user/xiliangdiao/firstpaper/ACCeast200-250.out",  delimiter=",")
fina3 = np.loadtxt(fname="/scratch/user/xiliangdiao/firstpaper/ACCeast250-300.out",  delimiter=",")
fina4 = np.loadtxt(fname="/scratch/user/xiliangdiao/firstpaper/ACCeast300-330.out",  delimiter=",")
xxx1 = np.hstack((final,fina2))
xxx2 = np.hstack((xxx1,fina3))
xxx3 = np.hstack((xxx2,fina4))

# %%
xx1final = xxx3[:2160]

# %%
# 读取文件 330-336
finalnew330 = np.loadtxt(fname="/scratch/user/xiliangdiao/firstpaper/ACCeast330-336.out",  delimiter=",")

# %%
# 读取文件
finalnew338 = np.loadtxt(fname="/scratch/user/xiliangdiao/firstpaper/ACC338-340east.out",  delimiter=",")

# %%
f338 = finalnew338[:24]

# %%
f330f340 = np.hstack((finalnew330,f338))
f330f340n = np.hstack((f330f340,f338))

# %%
f330f340n.shape
# Out:
# (120,)

# %%
# 读取文件
finalnew = np.loadtxt(fname="/scratch/user/xiliangdiao/firstpaper/ACC340-390east.out",  delimiter=",")
fina2new = np.loadtxt(fname="/scratch/user/xiliangdiao/firstpaper/ACC390-440east.out",  delimiter=",")
fina3new = np.loadtxt(fname="/scratch/user/xiliangdiao/firstpaper/ACC440-490east.out",  delimiter=",")
fina4new = np.loadtxt(fname="/scratch/user/xiliangdiao/firstpaper/ACC490-500east.out",  delimiter=",")
xxx1new = np.hstack((finalnew,fina2new))
xxx2new = np.hstack((xxx1new,fina3new))
xxx3new = np.hstack((xxx2new,fina4new))

# %%
xx = xxx3new[:1920]

# %%
fin1 = np.hstack((xx1final,f330f340n))
fin2 = np.hstack((fin1,xx))

# %%
fin2.shape
# Out:
# (4200,)

# %%
12*350
# Out:
# 4200

# %%
w = np.convolve(fin2, np.ones((60,))/60, mode='valid')

# %%
ww = np.convolve(xx, np.ones((60,))/60, mode='valid')

# %%
plt.plot(w)

# %%
plt.plot(ww)

# %%
t = np.arange(0,2160,1)
my_font = {'fontname':'Cambria', 'size':'16'}
##################################################################
fig = plt.figure(figsize=(18,10), dpi=100)
ax0 = fig.add_axes([0.1,0.1,0.7,0.7])
ax0.plot(w,'red',linewidth=3)
#########################################

plt.xticks(range(0,5161,240), ['150','170','190','210', '230', '250','270','290','310','330','350','370','390','410', '430', '450','470','490'],**my_font)
plt.yticks(**my_font)
plt.xlabel('Years',**my_font)
plt.xlabel('Years',**my_font)
plt.ylabel('(Sv)',color= 'red',**my_font)
#plt.hlines(mean, 0, 2160, colors = "k",linestyles = "dashed",linewidth=4)
plt.axis("tight")
#plt.plot([0,-ww2[0]],[320,2300])
ax0.set_title('Antarctic Circumpolar Current  (5 year running mean)',**my_font)
plt.savefig("ACCwest.png",bbox_inches='tight',dpi=fig.dpi)

# %%
np.savetxt('ACCwest.out',w)
