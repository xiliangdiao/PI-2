# %%
import netCDF4 as nc
import matplotlib.pyplot as plt
from matplotlib.colors import from_levels_and_colors
import numpy as np
from matplotlib import animation
from matplotlib.colors import BoundaryNorm
import matplotlib.colors as cols
import matplotlib as mpl
from mpl_toolkits.basemap import Basemap
from matplotlib import ticker, cm
import seaborn as sns

# %%
data1 = np.loadtxt("SOM21-61.out")
data2 = np.loadtxt("SOM61-101.out")
data3 = np.loadtxt("SOM101-141.out")
data4 = np.loadtxt("SOM141-191.out")
data5 = np.loadtxt("SOM191-241.out")
data6 = np.loadtxt("SOM241-291.out")
data7 = np.loadtxt("SOM291-331.out")

# %%
result = np.zeros(3720)
result[0:480] =data1
result[480:960] =data2
result[960:1440] =data3
result[1440:2040] =data4
result[2040:2640] =data5
result[2640:3240] =data6
result[3240:3720] =data7

# %%
result[1256]
# Out:
# 9.132147914734324

# %%
ww2 = np.convolve(result, np.ones((60,))/60, mode='valid')

# %%
mean = np.mean(ww2)
std = np.std(ww2)

# %%
SST = ww2 - mean

# %%
dataweddle = np.loadtxt("maudrise.out")
resultmaudrise = np.zeros(310)
resultmaudrise[:] = dataweddle
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-8-ae307879aaee> in <module>
#       1 dataweddle = np.loadtxt("maudrise.out")
#       2 resultmaudrise = np.zeros(310)
# ----> 3 resultmaudrise[:] = dataweddle
#
# ValueError: could not broadcast input array from shape (930) into shape (310)

# %%
ww1 = np.convolve(resultmaudrise, np.ones((5,))/5, mode='valid')

# %%
#t = np.arange(0,3181,1)
my_font = {'fontname':'Cambria', 'size':'16'}
##################################################################
fig = plt.figure(figsize=(20,5), dpi=100)
ax0 = fig.add_axes([0.1,0.1,0.7,0.7])
ax0.plot(SST,'red',linewidth=4)
plt.axhspan(std,0.65,facecolor='yellow', alpha=1)
plt.axhspan(-std,std,facecolor='lightblue', alpha=1)
plt.axhspan(-0.65,-std,facecolor='lightgreen', alpha=1)
plt.xticks(range(0,3720,240), ['20', '40', '60', '80','100','120','140','160',\
                            '180','200','220', '240', '260','280','300','320'],**my_font)
#plt.yticks(np.arange(-0.6,0.6,0.2), ['-0.6', '-0.4', '-0.2', '0','0.2','0.4','0.6'],**my_font)
plt.yticks(**my_font)
plt.xlabel('Years',**my_font)
plt.ylabel('SOM index($^\circ$C)',**my_font)
plt.axis("tight")
ax0.set(ylim=(-0.65, 0.65),xlim=(0, 3720))
ax0.set_title('South Ocean Mode  (50$^\circ$W - 0$^\circ$, 50$^\circ$S - 35$^\circ$S, averaged SST anomaly)',**my_font)
################################################
#ax2 = ax0.twinx() 
#ax2.plot(WDWF,'blue',linewidth=4)
plt.axvspan(0,(30-20)*12 +9,facecolor='lightgreen', alpha=1)
plt.axvspan((27-20)*12 +9,(28-20)*12 +9,facecolor='yellow', alpha=1)
plt.axvspan((30-20)*12 + 9,(39-20)*12 +9,facecolor='grey', alpha=1)
plt.axvspan((47-20)*12 + 9,(49-20)*12 +9,facecolor='yellow', alpha=1)
plt.axvspan((39-20)*12 + 9,(50-20)*12 +9,facecolor='lightgreen', alpha=1)
plt.axvspan((43-20)*12 + 9,(50-20)*12 +9,facecolor='yellow', alpha=1)
plt.axvspan((50-20)*12 + 9,(69-20)*12 +9,facecolor='grey', alpha=1)
plt.axvspan((56-20)*12 + 9,(57-20)*12 +9,facecolor='lightgreen', alpha=1)
plt.axvspan((69-20)*12 + 9,(86-20)*12 +9,facecolor='lightgreen', alpha=1)
plt.axvspan((70-20)*12 + 9,(79-20)*12 +9,facecolor='yellow', alpha=1)
plt.axvspan((86-20)*12 + 9,(94-20)*12 +9,facecolor='grey', alpha=1)
plt.axvspan((93-20)*12 + 9,(100-20)*12 +9,facecolor='lightgreen', alpha=1)
plt.axvspan((98-20)*12 + 9,(99-20)*12 +9,facecolor='yellow', alpha=1)
plt.axvspan((100-20)*12 + 9,(111-20)*12 +9,facecolor='grey', alpha=1)
plt.axvspan((106-20)*12 + 9,(108-20)*12 +9,facecolor='lightgreen', alpha=1)
plt.axvspan((111-20)*12 + 9,(118-20)*12 +9,facecolor='lightgreen', alpha=1)
plt.axvspan((116-20)*12 + 9,(118-20)*12 +9,facecolor='yellow', alpha=1)
plt.axvspan((118-20)*12 + 9,(119-20)*12 +9,facecolor='grey', alpha=1)
plt.axvspan((119-20)*12 + 9,(135-20)*12 +9,facecolor='yellow', alpha=1)
plt.axvspan((135-20)*12 + 9,(138-20)*12 +9,facecolor='grey', alpha=1)
plt.axvspan((138-20)*12 + 9,(149-20)*12 +9,facecolor='lightgreen', alpha=1)
plt.axvspan((140-20)*12 + 9,(142-20)*12 +9,facecolor='yellow', alpha=1)
plt.axvspan((149-20)*12 + 9,(152-20)*12 +9,facecolor='grey', alpha=1)
plt.axvspan((152-20)*12 + 9,(160-20)*12 +9,facecolor='yellow', alpha=1)
plt.axvspan((158-20)*12 + 9,(160-20)*12 +9,facecolor='lightgreen', alpha=1)
plt.axvspan((160-20)*12 + 9,(168-20)*12 +9,facecolor='grey', alpha=1)
plt.axvspan((168-20)*12 + 9,(200-20)*12 +9,facecolor='lightgreen', alpha=1)
plt.axvspan((174-20)*12 + 9,(196-20)*12 +9,facecolor='yellow', alpha=1)
plt.axvspan((196-20)*12 + 9,(199-20)*12 +9,facecolor='lightgreen', alpha=1)
plt.axvspan((181-20)*12 + 9,(183-20)*12 +9,facecolor='lightgreen', alpha=1)
plt.axvspan((200-20)*12 + 9,(203-20)*12 +9,facecolor='grey', alpha=1)
plt.axvspan((203-20)*12 + 9,(249-20)*12 +9,facecolor='lightgreen', alpha=1)
plt.axvspan((212-20)*12 + 9,(217-20)*12 +9,facecolor='yellow', alpha=1)
plt.axvspan((223-20)*12 + 9,(226-20)*12 +9,facecolor='yellow', alpha=1)
plt.axvspan((233-20)*12 + 9,(249-20)*12 +9,facecolor='yellow', alpha=1)
plt.axvspan((249-20)*12 + 9,(252-20)*12 +9,facecolor='grey', alpha=1)

plt.axvspan((252-20)*12 + 9,(290-20)*12 +9,facecolor='lightgreen', alpha=1)
plt.axvspan((255-20)*12 + 9,(256-20)*12 +9,facecolor='grey', alpha=1)
plt.axvspan((257-20)*12 + 9,(258-20)*12 +9,facecolor='lightgreen', alpha=1)
plt.axvspan((258-20)*12 + 9,(263-20)*12 +9,facecolor='yellow', alpha=1)
plt.axvspan((266-20)*12 + 9,(290-20)*12 +9,facecolor='yellow', alpha=1)
plt.axvspan((290-20)*12 + 9,(300-20)*12 +9,facecolor='grey', alpha=1)
plt.axvspan((300-20)*12 + 9,(321-20)*12 +9,facecolor='lightgreen', alpha=1)
plt.axvspan((304-20)*12 + 9,(319-20)*12 +9,facecolor='yellow', alpha=1)
plt.axvspan((321-20)*12 + 9,(330-20)*12 +9,facecolor='grey', alpha=1)
plt.axvspan((326-20)*12 + 9,(330-20)*12 +9,facecolor='lightgreen', alpha=1)

###################################
#plt.hlines(0, 0, 3720, colors = "g",linestyles = "dashed")
#plt.yticks(**my_font)
#plt.xlabel('Years',**my_font)
#plt.ylabel('WDW($^\circ$C)',**my_font)
#ax2.set(ylim=(-0.3, 0.3),xlim=(0, 3720))
########################################
plt.savefig("SOM.png",bbox_inches='tight',dpi=fig.dpi)

# %%
data1 = np.loadtxt("WDW21-61.out")
data2 = np.loadtxt("WDW61-111.out")
data3 = np.loadtxt("WDW111-161.out")
data4 = np.loadtxt("WDW161-211.out")
data5 = np.loadtxt("WDW211-261.out")
data6 = np.loadtxt("WDW261-331.out")

# %%
result2 = np.zeros(3720)
result2[0:480] =data1
result2[480:1080] =data2
result2[1080:1680] =data3
result2[1680:2280] =data4
result2[2280:2880] =data5
result2[2880:3720] =data6

# %%
WDW = np.convolve(result2, np.ones((60,))/60, mode='valid')

# %%
meanWDW = np.mean(WDW)
WDWF = WDW - meanWDW
stdW = np.std(WDW)

# %%
t = np.arange(0,3720,12)
my_font = {'fontname':'Cambria', 'size':'16'}
##################################################################
fig = plt.figure(figsize=(20,5), dpi=100)
ax0 = fig.add_axes([0.1,0.1,0.7,0.7])
ax0.plot(WDWF,'r',linewidth=4)
#plt.axhspan(0.05,0.3,facecolor='yellow', alpha=1)
#plt.axhspan(-0.05,0.05,facecolor='lightblue', alpha=1)
#plt.axhspan(-0.3,-0.05,facecolor='lightgreen', alpha=1)
plt.xticks(range(0,3720,240), ['20', '40', '60', '80','100','120','140','160',\
                            '180','200','220', '240', '260','280','300','320'],**my_font)
#plt.yticks(np.arange(-0.6,0.6,0.2), ['-0.6', '-0.4', '-0.2', '0','0.2','0.4','0.6'],**my_font)
plt.yticks(**my_font)
plt.xlabel('Years',**my_font)
plt.ylabel('WDW water($^\circ$C)',color = 'r',**my_font)
plt.axis("tight")
ax0.set(ylim=(-0.3, 0.3),xlim=(0, 3720))
#plt.vlines(1980, -0.3,0.3, colors = "g",linestyles = "dashed")
#plt.vlines(1200, -0.3,0.3, colors = "r",linestyles = "dashed")
################################################
#ax2 = ax0.twinx() 
#ax2.plot(BOWF,'blue',linewidth=4)
#ax2.set(ylim=(-0.25, 0.15),xlim=(0, 3720))

plt.axvspan(0,(30-20)*12 +9,facecolor='lightgreen', alpha=1)
plt.axvspan((27-20)*12 +9,(28-20)*12 +9,facecolor='yellow', alpha=1)
plt.axvspan((30-20)*12 + 9,(39-20)*12 +9,facecolor='grey', alpha=1)
plt.axvspan((47-20)*12 + 9,(49-20)*12 +9,facecolor='yellow', alpha=1)
plt.axvspan((39-20)*12 + 9,(50-20)*12 +9,facecolor='lightgreen', alpha=1)
plt.axvspan((43-20)*12 + 9,(50-20)*12 +9,facecolor='yellow', alpha=1)
plt.axvspan((50-20)*12 + 9,(69-20)*12 +9,facecolor='grey', alpha=1)
plt.axvspan((56-20)*12 + 9,(57-20)*12 +9,facecolor='lightgreen', alpha=1)
plt.axvspan((69-20)*12 + 9,(86-20)*12 +9,facecolor='lightgreen', alpha=1)
plt.axvspan((70-20)*12 + 9,(79-20)*12 +9,facecolor='yellow', alpha=1)
plt.axvspan((86-20)*12 + 9,(94-20)*12 +9,facecolor='grey', alpha=1)
plt.axvspan((93-20)*12 + 9,(100-20)*12 +9,facecolor='lightgreen', alpha=1)
plt.axvspan((98-20)*12 + 9,(99-20)*12 +9,facecolor='yellow', alpha=1)
plt.axvspan((100-20)*12 + 9,(111-20)*12 +9,facecolor='grey', alpha=1)
plt.axvspan((106-20)*12 + 9,(108-20)*12 +9,facecolor='lightgreen', alpha=1)
plt.axvspan((111-20)*12 + 9,(118-20)*12 +9,facecolor='lightgreen', alpha=1)
plt.axvspan((116-20)*12 + 9,(118-20)*12 +9,facecolor='yellow', alpha=1)
plt.axvspan((118-20)*12 + 9,(119-20)*12 +9,facecolor='grey', alpha=1)
plt.axvspan((119-20)*12 + 9,(135-20)*12 +9,facecolor='yellow', alpha=1)
plt.axvspan((135-20)*12 + 9,(138-20)*12 +9,facecolor='grey', alpha=1)
plt.axvspan((138-20)*12 + 9,(149-20)*12 +9,facecolor='lightgreen', alpha=1)
plt.axvspan((140-20)*12 + 9,(142-20)*12 +9,facecolor='yellow', alpha=1)
plt.axvspan((149-20)*12 + 9,(152-20)*12 +9,facecolor='grey', alpha=1)
plt.axvspan((152-20)*12 + 9,(160-20)*12 +9,facecolor='yellow', alpha=1)
plt.axvspan((158-20)*12 + 9,(160-20)*12 +9,facecolor='lightgreen', alpha=1)
plt.axvspan((160-20)*12 + 9,(168-20)*12 +9,facecolor='grey', alpha=1)
plt.axvspan((168-20)*12 + 9,(200-20)*12 +9,facecolor='lightgreen', alpha=1)
plt.axvspan((174-20)*12 + 9,(196-20)*12 +9,facecolor='yellow', alpha=1)
plt.axvspan((196-20)*12 + 9,(199-20)*12 +9,facecolor='lightgreen', alpha=1)
plt.axvspan((181-20)*12 + 9,(183-20)*12 +9,facecolor='lightgreen', alpha=1)
plt.axvspan((200-20)*12 + 9,(203-20)*12 +9,facecolor='grey', alpha=1)
plt.axvspan((203-20)*12 + 9,(249-20)*12 +9,facecolor='lightgreen', alpha=1)
plt.axvspan((212-20)*12 + 9,(217-20)*12 +9,facecolor='yellow', alpha=1)
plt.axvspan((223-20)*12 + 9,(226-20)*12 +9,facecolor='yellow', alpha=1)
plt.axvspan((233-20)*12 + 9,(249-20)*12 +9,facecolor='yellow', alpha=1)
plt.axvspan((249-20)*12 + 9,(252-20)*12 +9,facecolor='grey', alpha=1)

plt.axvspan((252-20)*12 + 9,(290-20)*12 +9,facecolor='lightgreen', alpha=1)
plt.axvspan((255-20)*12 + 9,(256-20)*12 +9,facecolor='grey', alpha=1)
plt.axvspan((257-20)*12 + 9,(258-20)*12 +9,facecolor='lightgreen', alpha=1)
plt.axvspan((258-20)*12 + 9,(263-20)*12 +9,facecolor='yellow', alpha=1)
plt.axvspan((266-20)*12 + 9,(290-20)*12 +9,facecolor='yellow', alpha=1)
plt.axvspan((290-20)*12 + 9,(300-20)*12 +9,facecolor='grey', alpha=1)
plt.axvspan((300-20)*12 + 9,(321-20)*12 +9,facecolor='lightgreen', alpha=1)
plt.axvspan((304-20)*12 + 9,(319-20)*12 +9,facecolor='yellow', alpha=1)
plt.axvspan((321-20)*12 + 9,(330-20)*12 +9,facecolor='grey', alpha=1)
plt.axvspan((326-20)*12 + 9,(330-20)*12 +9,facecolor='lightgreen', alpha=1)
###################################
#plt.hlines(0, 0, 3720, colors = "g",linestyles = "dashed")
plt.yticks(**my_font)
plt.xlabel('Years',**my_font)
#plt.ylabel('AABW($^\circ$C)',color = 'blue',**my_font)
plt.savefig("WDW.png",bbox_inches='tight',dpi=fig.dpi)

# %%
data1 = np.loadtxt("BOW21-71.out")
data2 = np.loadtxt("BOW71-121.out")
data3 = np.loadtxt("BOW121-171.out")
data4 = np.loadtxt("BOW171-221.out")
data5 = np.loadtxt("BOW221-271.out")
data6 = np.loadtxt("BOW271-331.out")

# %%
result3 = np.zeros(3720)
result3[0:600] =data1
result3[600:1200] =data2
result3[1200:1800] =data3
result3[1800:2400] =data4
result3[2400:3000] =data5
result3[3000:3720] =data6

# %%
BOW = np.convolve(result3, np.ones((60,))/60, mode='valid')

# %%
BOWmean = np.mean(BOW)
BOWF = BOW - BOWmean

# %%
#t = np.arange(0,3181,1)
my_font = {'fontname':'Cambria', 'size':'16'}
##################################################################
fig = plt.figure(figsize=(20,5), dpi=100)
ax0 = fig.add_axes([0.1,0.1,0.7,0.7])
ax0.plot(SST,'r',linewidth=4)
plt.axhspan(std,0.65,facecolor='yellow', alpha=1)
plt.axhspan(-std,std,facecolor='lightblue', alpha=1)
plt.axhspan(-0.65,-std,facecolor='lightgreen', alpha=1)
plt.xticks(range(0,3720,240), ['20', '40', '60', '80','100','120','140','160',\
                            '180','200','220', '240', '260','280','300','320'],**my_font)
#plt.yticks(np.arange(-0.6,0.6,0.2), ['-0.6', '-0.4', '-0.2', '0','0.2','0.4','0.6'],**my_font)
plt.yticks(**my_font)
plt.xlabel('Years',**my_font)
plt.ylabel('SOM index($^\circ$C)',color = 'r',**my_font)
plt.axis("tight")
ax0.set(ylim=(-0.65, 0.65),xlim=(0, 3720))

################################################
ax2 = ax0.twinx() 
ax2.plot(WDWF,'blue',linewidth=4)
ax2.set(ylim=(-0.3, 0.3),xlim=(0, 3720))
#plt.vlines(1980, -0.3,0.3, colors = "g",linestyles = "dashed")
###################################
#plt.hlines(0, 0, 3720, colors = "g",linestyles = "dashed")
plt.yticks(**my_font)
plt.xlabel('Years',**my_font)
plt.ylabel('WDW($^\circ$C)',color = 'blue',**my_font)
plt.savefig("WDW2.png",bbox_inches='tight',dpi=fig.dpi)

# %%
dataweddle = np.loadtxt("weddle.out")
resultmaudrise = np.zeros(310)
resultmaudrise[:] = dataweddle
