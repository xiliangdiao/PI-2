# %%
import netCDF4 as nc
import matplotlib.pyplot as plt
from matplotlib.colors import from_levels_and_colors
import numpy as np
from matplotlib import animation
from matplotlib.colors import BoundaryNorm
import matplotlib.colors as cols
import matplotlib as mpl
from mpl_toolkits.basemap import Basemap
from matplotlib import ticker, cm
import seaborn as sns

# %%
result1 = np.zeros((3720))
i = 0

# %%
months = [f"{x:02d}" for x in range(1,13)]
years = [f"{x:04d}" for x in range(21,331)]
i =0
for yy in years:
    for mm in months:
        data=nc.Dataset('/ihesp/user/xiliangdiao/ihespdata/ocn300/B.E.13.B1850C5.ne120_t12.sehires38.003.sunway_02.pop.h.'+yy+'-'+mm +'.HMXL.nc')
        plotvar = data.variables['HMXL'][0,:,:]
        plotvar[plotvar == -1.0] = np.nan
        lont = data.variables['TLONG']
        latt = data.variables['TLAT']
        lont = lont[201:365,650:900]
        latt = latt[201:365,650:900]
        plot1 = plotvar[201:365,650:900]
        aveplot = np.nanmax(plot1)
    
        result1[i] = aveplot
        i = i + 1

# %%
ww2 = np.convolve(result1, np.ones((60,))/60, mode='valid')

# %%
my_font = {'fontname':'Cambria', 'size':'16'}
##################################################################
fig = plt.figure(figsize=(20,5), dpi=100)
ax0 = fig.add_axes([0.1,0.1,0.7,0.7])
ax0.plot(result1/100,'red')
#plt.axhspan(std,0.65,facecolor='yellow', alpha=1)
#plt.axhspan(-std,std,facecolor='lightblue', alpha=1)
#plt.axhspan(-0.65,-std,facecolor='lightgreen', alpha=1)
plt.xticks(range(0,3720,240), ['20', '40', '60', '80','100','120','140','160',\
                            '180','200','220', '240', '260','280','300','320'],**my_font)
#plt.yticks(np.arange(-0.6,0.6,0.2), ['-0.6', '-0.4', '-0.2', '0','0.2','0.4','0.6'],**my_font)
plt.yticks(**my_font)
plt.xlabel('Years',**my_font)
plt.ylabel('Mix Layer Depth(m)',**my_font)
plt.axis("tight")

ax0.invert_yaxis()
#ax0.set(ylim=(-0.65, 0.65),xlim=(0, 3720))
ax0.set_title('Mix Layer Depth Max Value(63$^\circ$S - 70$^\circ$S, 45$^\circ$W - 20$^\circ$W)',**my_font)
################################################
#ax2 = ax0.twinx() 
#ax2.plot(WDWF,'blue',linewidth=4)


###################################
#plt.hlines(0, 0, 3720, colors = "g",linestyles = "dashed")
#plt.yticks(**my_font)
#plt.xlabel('Years',**my_font)
#plt.ylabel('WDW($^\circ$C)',**my_font)
#ax2.set(ylim=(-0.3, 0.3),xlim=(0, 3720))
########################################
plt.savefig("MXL.png",bbox_inches='tight',dpi=fig.dpi)
