# %%
import netCDF4 as nc
import matplotlib.pyplot as plt
from matplotlib.colors import from_levels_and_colors
import numpy as np
from matplotlib import animation
from matplotlib.colors import BoundaryNorm
import matplotlib.colors as cols
import matplotlib as mpl
from mpl_toolkits.basemap import Basemap
from matplotlib import ticker, cm
import seaborn as sns

# %%
# 读取文件
final = np.loadtxt(fname="/scratch/user/xiliangdiao/firstpaper/stream150-170.out",  delimiter=",")
fina2 = np.loadtxt(fname="/scratch/user/xiliangdiao/firstpaper/stream170-190.out",  delimiter=",")
fina3 = np.loadtxt(fname="/scratch/user/xiliangdiao/firstpaper/stream190-210.out",  delimiter=",")
fina4 = np.loadtxt(fname="/scratch/user/xiliangdiao/firstpaper/stream210-230.out",  delimiter=",")
fina5 = np.loadtxt(fname="/scratch/user/xiliangdiao/firstpaper/stream230-250.out",  delimiter=",")
fina6 = np.loadtxt(fname="/scratch/user/xiliangdiao/firstpaper/stream250-270.out",  delimiter=",")
fina7 = np.loadtxt(fname="/scratch/user/xiliangdiao/firstpaper/stream270-290.out",  delimiter=",")
fina8 = np.loadtxt(fname="/scratch/user/xiliangdiao/firstpaper/stream290-310.out",  delimiter=",")
fina9 = np.loadtxt(fname="/scratch/user/xiliangdiao/firstpaper/stream310-330.out",  delimiter=",")

# %%
result = np.zeros(180)
result[0:20] =final
result[20:40] =fina2
result[40:60] =fina3
result[60:80] =fina4
result[80:100] =fina5
result[100:120] =fina6
result[120:140] =fina7
result[140:160] =fina8
result[160:180] =fina9

# %%
SV = -result/1000000

# %%
# 12 months average pattern (300years)
plt.plot(SV)

# %%
t = np.arange(0,60,1)
my_font = {'fontname':'Cambria', 'size':'16'}
##################################################################
fig = plt.figure(figsize=(18,10), dpi=100)
ax0 = fig.add_axes([0.1,0.1,0.7,0.7])
ax0.plot(SV,'red',linewidth=3)
#########################################

plt.xticks(range(0,181,20), ['150','170','190','210', '230', '250','270','290','310','330'],**my_font)
plt.yticks(**my_font)
plt.xlabel('Years',**my_font)
plt.xlabel('Years',**my_font)
plt.ylabel('Stream Fuction(Sv)',color= 'red',**my_font)
plt.axis("tight")
# Out:
# (-8.950000000000001, 187.95, 53.510888152977046, 123.27856890557706)

# %%
t = np.arange(0,2160,12)
my_font = {'fontname':'Cambria', 'size':'16'}
##################################################################
fig = plt.figure(figsize=(20,5), dpi=100)
ax0 = fig.add_axes([0.1,0.1,0.7,0.7])
ax0.plot(t,SV,'purple',linewidth=3)
#########################################

##########################################################################
plt.axvspan((149-20-130)*12 + 9,(152-20-130)*12 +9,facecolor='grey', alpha=1)
plt.axvspan((152-20-130)*12 + 9,(160-20-130)*12 +9,facecolor='yellow', alpha=1)
plt.axvspan((152-20-130)*12 + 9,(154-20-130)*12 +9,facecolor='green', alpha=1)
plt.axvspan((157-20-130)*12 + 9,(160-20-130)*12 +9,facecolor='blue', alpha=1)
plt.axvspan((160-20-130)*12 + 9,(168-20-130)*12 +9,facecolor='grey', alpha=1)
plt.axvspan((167-20-130)*12 + 9,(200-20-130)*12 +9,facecolor='blue', alpha=1)
plt.axvspan((174-20-130)*12 + 9,(196-20-130)*12 +9,facecolor='yellow', alpha=1)
plt.axvspan((196-20-130)*12 + 9,(199-20-130)*12 +9,facecolor='green', alpha=1)
plt.axvspan((181-20-130)*12 + 9,(183-20-130)*12 +9,facecolor='green', alpha=1)
plt.axvspan((200-20-130)*12 + 9,(203-20-130)*12 +9,facecolor='grey', alpha=1)
plt.axvspan((203-20-130)*12 + 9,(240-20-130)*12 +9,facecolor='green', alpha=1)
plt.axvspan((240-20-130)*12 + 9,(249-20-130)*12 +9,facecolor='yellow', alpha=1)
plt.axvspan((210-20-130)*12 + 9,(211-20-130)*12 +9,facecolor='blue', alpha=1)

plt.axvspan((212-20-130)*12 + 9,(217-20-130)*12 +9,facecolor='yellow', alpha=1)
plt.axvspan((223-20-130)*12 + 9,(226-20-130)*12 +9,facecolor='yellow', alpha=1)
plt.axvspan((231-20-130)*12 + 9,(232-20-130)*12 +9,facecolor='blue', alpha=1)
plt.axvspan((233-20)*12 + 9,(249-20-130)*12 +9,facecolor='yellow', alpha=1)
plt.axvspan((248-20-130)*12 + 9,(249-20-130)*12 +9,facecolor='blue', alpha=1)
plt.axvspan((249-20-130)*12 + 9,(252-20-130)*12 +9,facecolor='grey', alpha=1)
#plt.axvspan((235-20)*12 + 9,(249-20-130)*12 +9,facecolor='yellow', alpha=1)

plt.axvspan((252-20-130)*12 + 9,(290-20-130)*12 +9,facecolor='blue', alpha=1)
plt.axvspan((254-20-130)*12 + 9,(256-20-130)*12 +9,facecolor='grey', alpha=1)
plt.axvspan((257-20-130)*12 + 9,(258-20-130)*12 +9,facecolor='green', alpha=1)
plt.axvspan((258-20-130)*12 + 9,(263-20-130)*12 +9,facecolor='yellow', alpha=1)
plt.axvspan((261-20-130)*12 + 9,(262-20-130)*12 +9,facecolor='blue', alpha=1)
plt.axvspan((264-20-130)*12 + 9,(265-20-130)*12 +9,facecolor='blue', alpha=1)

plt.axvspan((266-20-130)*12 + 9,(290-20-130)*12 +9,facecolor='yellow', alpha=1)
plt.axvspan((290-20-130)*12 + 9,(300-20-130)*12 +9,facecolor='grey', alpha=1)
plt.axvspan((300-20-130)*12 + 9,(321-20-130)*12 +9,facecolor='green', alpha=1)
plt.axvspan((304-20-130)*12 + 9,(319-20-130)*12 +9,facecolor='yellow', alpha=1)
plt.axvspan((321-20-130)*12 + 9,(330-20-130)*12 +9,facecolor='grey', alpha=1)
plt.axvspan((326-20-130)*12 + 9,(330-20-130)*12 +9,facecolor='green', alpha=1)



plt.xticks(range(0,2160,240), ['150','170','190','210','230', '250', '270','290','310'],**my_font)
plt.yticks(**my_font)
plt.xlabel('Years',**my_font)
plt.xlabel('Years',**my_font)
plt.ylabel('Stream Fuction(Sv)',color= 'purple',**my_font)
ax0.set_title('Stream Function for the Weddell Gyre (Only September)',**my_font)
plt.axis("tight")
ax0.set(xlim=(0, 2160))

plt.savefig("streamf.png",bbox_inches='tight',dpi=fig.dpi)

# %%
180*12
# Out:
# 2160
