# %%
import netCDF4 as nc
import matplotlib.pyplot as plt
from matplotlib.colors import from_levels_and_colors
import numpy as np
from matplotlib import animation
from matplotlib.colors import BoundaryNorm
import matplotlib.colors as cols
import matplotlib as mpl
#from mpl_toolkits.basemap import Basemap
from matplotlib import ticker, cm
import seaborn as sns

# %%
ww2 = np.loadtxt("dvi.out")

# %%
wspxx = np.loadtxt("wspxx2.out")
mrpxx = np.loadtxt("mrpxx2.out")
#noxx = np.loadtxt("noxx.out")

# %%
t = np.arange(2,348,1)
my_font = {'fontname':'Cambria', 'size':'16'}
##################################################################
fig = plt.figure(figsize=(20,5), dpi=100)
ax0 = fig.add_axes([0.1,0.1,0.7,0.7])
#plt.vlines(noxx, -0.125, 0.06,colors = "grey",linewidth=3)
plt.vlines(mrpxx, -0.125, 0.06, colors = "lightgrey",linewidth=3)
plt.vlines(wspxx, -0.125, 0.06, colors = "grey",linewidth=3)

plt.vlines(310, 0, 0.06, colors = "red",linewidth=3)
plt.vlines(319, 0, 0.06, colors = "red",linewidth=3)

plt.vlines(280, -0.125, 0, colors = "purple",linewidth=3)
plt.vlines(289, -0.125, 0, colors = "purple",linewidth=3)

ax0.plot(t,ww2*917/1000,'blue',linewidth=4)
plt.hlines(0, 0, 350, colors = "red",linestyles = "dashed")
plt.xticks(range(0,350,20), ['150','170','190','210','230', '250', '270','290','310','330','350', '370', '390','410','430','450','470','490','500'],**my_font)
#plt.yticks(np.arange(-0.6,0.6,0.2), ['-0.6', '-0.4', '-0.2', '0','0.2','0.4','0.6'],**my_font)
plt.yticks(**my_font)
plt.xlabel('Years',**my_font)
plt.ylabel('freshwater flux (cm/day)',**my_font)
plt.axis("tight")
ax0.set(ylim=(-0.125, 0.06),xlim=(0, 350))
ax0.set_title('Sea ice induced freshwater flux in the Central Weddell Sea (30$^\circ$W - 0$^\circ$E, 63$^\circ$S - 68$^\circ$S,  5 Year running mean data)',**my_font)
plt.savefig("dvi1.png",bbox_inches='tight',dpi=fig.dpi)
# Out:
# findfont: Font family ['Cambria'] not found. Falling back to DejaVu Sans.

# %%
ww2rr = np.loadtxt("dvirr2.out")

# %%
t = np.arange(0,350,1)
my_font = {'fontname':'Cambria', 'size':'16'}
##################################################################
fig = plt.figure(figsize=(20,5), dpi=100)
ax0 = fig.add_axes([0.1,0.1,0.7,0.7])
#plt.vlines(noxx, -0.25, 0.11,colors = "grey",linewidth=3)
plt.vlines(mrpxx, -0.25, 0.11, colors = "lightgrey",linewidth=3)
plt.vlines(wspxx, -0.25, 0.11, colors = "grey",linewidth=3)
ax0.plot(t,ww2rr,'red',linewidth=4)
plt.hlines(0, 0, 350, colors = "red",linestyles = "dashed")
plt.xticks(range(0,350,20), ['150','170','190','210','230', '250', '270','290','310','330','350', '370', '390','410','430','450','470','490','500'],**my_font)
#plt.yticks(np.arange(-0.6,0.6,0.2), ['-0.6', '-0.4', '-0.2', '0','0.2','0.4','0.6'],**my_font)
plt.yticks(**my_font)
plt.xlabel('Years',**my_font)
plt.ylabel('dvidtt (cm/day)',**my_font)
plt.axis("tight")
ax0.set(ylim=(-0.25, 0.11),xlim=(0, 350))
ax0.set_title('dvidtt averaged over Maud Rise and Astrid Ridge (0$^\circ$ - 20$^\circ$E, 63$^\circ$S - 68$^\circ$S, Yearly mean data)',**my_font)
plt.savefig("dvi2.png",bbox_inches='tight',dpi=fig.dpi)
