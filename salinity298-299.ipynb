# %%
import netCDF4 as nc
import matplotlib.pyplot as plt
from matplotlib.colors import from_levels_and_colors
import numpy as np
from matplotlib import animation
from matplotlib.colors import BoundaryNorm
import matplotlib.colors as cols
import matplotlib as mpl
from mpl_toolkits.basemap import Basemap
from matplotlib import ticker, cm
import seaborn as sns

# %%
months = [f"{x:02d}" for x in range(1,13)]
years = [f"{x:04d}" for x in range(297,301)]
i =0
result = np.zeros((48))

# %%
for yy in years:
    for mm in months:

        data=nc.Dataset('/ihesp/user/xiliangdiao/data/ihespdata/ocn300/B.E.13.B1850C5.ne120_t12.sehires38.003.sunway_02.pop.h.'+yy+'-'+mm +'.SALT.nc')
        plotvar = data.variables['SALT'][0,:,:]
        lont = data.variables['TLONG']
        latt = data.variables['TLAT']
        plotvar = plotvar[0,318,1200]
        #plotvar[plotvar == -1.0] = np.nan
        #aveplot = np.nanmean(plotvar,axis=1)
        #aveplot = np.nanmean(plotvar,axis=0)
        result[i] = plotvar
        
        i = i + 1
#********************************************************************

# %%
latt[318,1200]
# Out:
# masked_array(data=-65.03360438,
#              mask=False,
#        fill_value=1e+20)

# %%
result.shape
# Out:
# (48,)

# %%
my_font = {'fontname':'Cambria', 'size':'16'}
##################################################################
fig = plt.figure(figsize=(18,7), dpi=100)
ax0 = fig.add_axes([0.1,0.1,0.7,0.7])
ax0.plot(result,'r-o',linewidth=4)

#########################################

plt.xticks(range(0,49,6), ['297','(July)','298','(July)','299','(July)','300','(July)', '301','(July)', '2008','2018','290','310','330'],**my_font)
plt.yticks(**my_font)
plt.vlines(45,34.0,34.75,  colors = "grey",linewidth=60)
plt.vlines(42,34.0,34.75,  colors = "grey",linewidth=1)
plt.vlines(30,34.0,34.75,  colors = "grey",linewidth=1)
plt.vlines(18,34.0,34.75,  colors = "grey",linewidth=1)
plt.vlines(6,34.0,34.75,  colors = "grey",linewidth=1)
plt.xlabel('Years',**my_font)
plt.xlabel('Years',**my_font)
plt.ylabel('psu',color= 'red',**my_font)
plt.hlines(34.55, 0, 49, colors = "b",linestyles = "dashed",linewidth=4)
#plt.hlines(mean, 0, 2160, colors = "k",linestyles = "dashed",linewidth=4)
plt.axis("tight")
#plt.plot([0,-ww2[0]],[320,2300])
ax0.set_title('Mixed-layer (top 50m) Salinity (65$^\circ$S ,10$^\circ$E, one point)',**my_font)
plt.savefig("SSS.png",bbox_inches='tight',dpi=fig.dpi)
# Out:
# findfont: Font family ['Cambria'] not found. Falling back to DejaVu Sans.

# %%
np.savetxt('onepointSSS.out', result)

# %%
data=nc.Dataset('/ihesp/user/xiliangdiao/ihespdata/ice300/B.E.13.B1850C5.ne120_t12.sehires38.003.sunway_02.cice.h.0089-07.fsalt.nc')

# %%
data.variables['fsalt_ai']
# Out:
# <class 'netCDF4._netCDF4.Variable'>
# float32 fsalt_ai(time, nj, ni)
#     _FillValue: 1e+30
#     units: kg/m^2/day
#     long_name: salt flux ice to ocean
#     coordinates: TLON TLAT time
#     cell_measures: area: tarea
#     missing_value: 1e+30
#     comment: weighted by ice area
#     cell_methods: time: mean
#     time_rep: averaged
# unlimited dimensions: time
# current shape = (1, 601, 3600)
# filling on

# %%
salt[0,318,1200]
# Out:
# masked_array(data=-0.02848648,
#              mask=False,
#        fill_value=1e+20,
#             dtype=float32)

# %%
latt[272:343,1150:1250]
# Out:
# masked_array(data=[-66.97764789, -66.93538608, -66.89312426, -66.85086245,
#                    -66.80860063, -66.76633882, -66.724077  , -66.68181519,
#                    -66.63955337, -66.59729156, -66.55502974, -66.51276793,
#                    -66.47050611, -66.4282443 , -66.38598248, -66.34372067,
#                    -66.30145885, -66.25919703, -66.21693522, -66.1746734 ,
#                    -66.13241159, -66.09014977, -66.04788796, -66.00562614,
#                    -65.96336433, -65.92110251, -65.8788407 , -65.83657888,
#                    -65.79431707, -65.75205525, -65.70979343, -65.66753162,
#                    -65.6252698 , -65.58300799, -65.54074617, -65.49848436,
#                    -65.45622254, -65.41396073, -65.37169891, -65.32943709,
#                    -65.28717528, -65.24491346, -65.20265165, -65.16038983,
#                    -65.11812802, -65.0758662 , -65.03360438, -64.99134257,
# ...

# %%
months = [f"{x:02d}" for x in range(1,13)]
years = [f"{x:04d}" for x in range(297,301)]
i =0
result = np.zeros((48))

# %%
for yy in years:
    for mm in months:

        data=nc.Dataset('/ihesp/user/xiliangdiao/ihespdata/ice300/B.E.13.B1850C5.ne120_t12.sehires38.003.sunway_02.cice.h.'+yy+'-'+mm +'.fsalt.nc')
        plotvar = data.variables['fsalt'][0,:,:]
        #plotvar = plotvar[272:343,1150:1250]
        #plotvar[plotvar == -1.0] = np.nan
        plotvar = plotvar[318,1200]
        #aveplot = np.nanmean(plotvar,axis=1)
        #aveplot = np.nanmean(aveplot,axis=0)
        result[i] = plotvar
        
        i = i + 1
#********************************************************************

# %%
result
# Out:
# array([ 5.54008901e-01,  7.17377841e-01,  2.94779152e-01,  0.00000000e+00,
#         0.00000000e+00, -3.15331593e-02, -7.40337605e-03, -1.27911298e-02,
#        -5.28587261e-04, -5.05497563e-04,  4.65046428e-03,  5.28864637e-02,
#         4.09477443e-01,  5.49944520e-01,  2.38701329e-01,  0.00000000e+00,
#        -1.90779045e-02, -2.50113327e-02, -7.53641035e-03,  9.96680930e-03,
#         1.62549019e-02,  4.36237548e-03,  2.85821315e-02,  3.74460131e-01,
#         6.99917316e-01,  4.30456728e-01,  0.00000000e+00,  0.00000000e+00,
#         0.00000000e+00, -1.48319416e-02, -9.03075933e-03,  7.19542522e-03,
#         6.95767486e-03,  6.38392195e-03,  1.31469732e-02,  1.53885022e-01,
#         6.97400749e-01,  6.48060322e-01,  2.09797353e-01,  0.00000000e+00,
#         0.00000000e+00, -1.07970461e-02, -1.30905835e-02,  3.14699076e-02,
#         4.91705954e-01,  6.52708352e-01,  4.26188022e-01,  7.20490813e-01])

# %%
my_font = {'fontname':'Cambria', 'size':'16'}
##################################################################
fig = plt.figure(figsize=(18,10), dpi=100)
ax0 = fig.add_axes([0.1,0.1,0.7,0.7])
ax0.plot(result,'r-o',linewidth=3)

#########################################

plt.xticks(range(0,49,6), ['297','(July)','298','(July)','299','(July)','300','(July)', '301','(July)', '2008','2018','290','310','330'],**my_font)
plt.yticks(**my_font)
plt.xlabel('Years',**my_font)
plt.xlabel('Years',**my_font)
plt.ylabel('kg/m^2/day',color= 'red',**my_font)
plt.hlines(0, 0, 49, colors = "k",linestyles = "dashed",linewidth=4)
#plt.hlines(mean, 0, 2160, colors = "k",linestyles = "dashed",linewidth=4)
plt.axis("tight")
#plt.plot([0,-ww2[0]],[320,2300])
ax0.set_title('(fsalt)salt flux ice to ocn (cpl) (65$^\circ$S ,10$^\circ$E, one point) --if positive, ocean gains salt',**my_font)
plt.savefig("fsalt.png",bbox_inches='tight',dpi=fig.dpi)
# Out:
# findfont: Font family ['Cambria'] not found. Falling back to DejaVu Sans.

# %%
months = [f"{x:02d}" for x in range(1,13)]
years = [f"{x:04d}" for x in range(297,301)]
i =0
result = np.zeros((48))

# %%
for yy in years:
    for mm in months:

        data=nc.Dataset('/ihesp/user/xiliangdiao/ihespdata/ice300/B.E.13.B1850C5.ne120_t12.sehires38.003.sunway_02.cice.h.'+yy+'-'+mm +'.fsalt-ai.nc')
        plotvar = data.variables['fsalt_ai'][0,:,:]
        #plotvar = plotvar[272:343,1150:1250]
        #plotvar[plotvar == -1.0] = np.nan
        plotvar = plotvar[318,1200]
        #aveplot = np.nanmean(plotvar,axis=1)
        #aveplot = np.nanmean(aveplot,axis=0)
        result[i] = plotvar
        
        i = i + 1
#********************************************************************

# %%
my_font = {'fontname':'Cambria', 'size':'16'}
##################################################################
fig = plt.figure(figsize=(18,10), dpi=100)
ax0 = fig.add_axes([0.1,0.1,0.7,0.7])
ax0.plot(result,'r-o',linewidth=3)

#########################################

plt.xticks(range(0,49,6), ['297','(July)','298','(July)','299','(July)','300','(July)', '301','(July)', '2008','2018','290','310','330'],**my_font)
plt.yticks(**my_font)
plt.xlabel('Years',**my_font)
plt.xlabel('Years',**my_font)
plt.ylabel('kg/m^2/day',color= 'red',**my_font)
plt.hlines(0, 0, 49, colors = "k",linestyles = "dashed",linewidth=4)
#plt.hlines(mean, 0, 2160, colors = "k",linestyles = "dashed",linewidth=4)
plt.axis("tight")
#plt.plot([0,-ww2[0]],[320,2300])
ax0.set_title('(fsalt_ai)salt flux ice to ocn (weighted by ice area) (65$^\circ$S ,10$^\circ$E, one point)',**my_font)
plt.savefig("fsalt-ai.png",bbox_inches='tight',dpi=fig.dpi)
