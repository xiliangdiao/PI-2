# %%
import netCDF4 as nc
import matplotlib.pyplot as plt
from matplotlib.colors import from_levels_and_colors
import numpy as np
from matplotlib import animation
from matplotlib.colors import BoundaryNorm
import matplotlib.colors as cols
import matplotlib as mpl
from mpl_toolkits.basemap import Basemap
from matplotlib import ticker, cm
import seaborn as sns

# %%
result = np.zeros((181))
i=0

# %%
# 224:343 --------- 64S-69S
months = [f"{x:02d}" for x in range(9,10)]
years = [f"{x:04d}" for x in range(150,331)]
i =0
for yy in years:
    for mm in months:
        data=nc.Dataset('/ihesp/user/xiliangdiao/data/ihespdata/ice300/B.E.13.B1850C5.ne120_t12.sehires38.003.sunway_02.cice.h.'+yy+'-'+mm +'.hi.nc')
        plotvar = data.variables['hi'][0,:,:]
        plotvar = plotvar[247:365,700:1300]
        #plotvar = plotvar[224:343,600:1400]
        aveplot = plotvar.mean(axis=0)
        aveplot = aveplot.mean(axis=0)
        result[i] = aveplot
        
        i = i + 1

# %%
wspxx = np.loadtxt("wspxx2.out")
mrpxx = np.loadtxt("mrpxx2.out")
noxx = np.loadtxt("noxx2.out")

# %%
my_font = {'fontname':'Cambria', 'size':'16'}
##################################################################
fig = plt.figure(figsize=(20,5), dpi=100)
ax0 = fig.add_axes([0.1,0.1,0.7,0.7])
ax0.plot(result,'r',linewidth=3)
#plt.hlines(nn, 0, 4150, colors = "b",linestyles = "dashed")
#ax0.plot(tem,'red',linewidth=3)
#########################################
plt.vlines(noxx, 0.3,1.3, colors = "grey",linewidth=3)
plt.vlines(mrpxx, 0.3,1.3, colors = "blue",linewidth=3)
plt.vlines(wspxx, 0.3,1.3, colors = "yellow",linewidth=3)
#plt.hlines(70, 0, 350, colors = "black",linestyles = "dashed")
plt.xticks(range(0,350,50), ['150','200','250','300', '350', '400','450','500'],**my_font)
plt.yticks(**my_font)
plt.xlabel('Years',**my_font)
plt.xlabel('Years',**my_font)
plt.ylabel('(%)',color= 'b',**my_font)
plt.axis("tight")
#ax0.set(ylim=(25, 97),xlim=(0, 350))
ax0.set_title('Sea Ice Concentration (64$^\circ$S - 69$^\circ$S,50$^\circ$W - 20$^\circ$E )',**my_font)
#plt.savefig("seaice.png",bbox_inches='tight',dpi=fig.dpi)
# Out:
# Text(0.5, 1.0, 'Sea Ice Concentration (64$^\\circ$S - 69$^\\circ$S,50$^\\circ$W - 20$^\\circ$E )')
# findfont: Font family ['Cambria'] not found. Falling back to DejaVu Sans.

# %%
result33 = np.zeros((7))
i = 0

# %%
months = [f"{x:02d}" for x in range(9,10)]
years = [f"{x:04d}" for x in range(331,338)]
i =0
for yy in years:
    for mm in months:
        data=nc.Dataset('/scratch/user/xiliangdiao/figures/hi_B.E.13.B1850C5.ne120_t12.sehires38.003.sunway_02.cice.h.'+yy+'-'+mm +'.nc')
        plotvar = data.variables['hi'][0,:,:]
        plotvar[plotvar == -1.0] = np.nan
        plot1 = plotvar[247:365,700:1300]
        #plot1 = plotvar[224:343,600:1400]
        plot1 = np.nanmean(plot1, axis = 0)
        aveplot = np.nanmean(plot1,axis=0)
    
        result33[i] = aveplot
        i = i + 1

# %%
pwd
# Out:
# '/scratch/user/xiliangdiao/plot-PI'

# %%
result1 = np.zeros((156))
i=0

# %%
# 224:343 --------- 64S-69S
months = [f"{x:02d}" for x in range(9,10)]
years = [f"{x:04d}" for x in range(338,494)]
i =0
for yy in years:
    for mm in months:
        data=nc.Dataset('/ihesp/user/xiliangdiao/data/ihespdata/ice500/cmpr_B.E.13.B1850C5.ne120_t12.sehires38.003.sunway_02.cice.h.'+yy+'-'+mm +'.hi.nc')
        plotvar = data.variables['hi'][0,:,:]
        plotvar = plotvar[247:365,700:1300]
        #plotvar = plotvar[224:343,600:1400]
        aveplot = plotvar.mean(axis=0)
        aveplot = aveplot.mean(axis=0)
        result1[i] = aveplot
        
        i = i + 1

# %%
plt.plot(result1)

# %%
resultnew3 = np.zeros((5))
i=0

# %%
# 224:343 --------- 64S-69S
months = [f"{x:02d}" for x in range(9,10)]
years = [f"{x:04d}" for x in range(495,500)]
i =0
for yy in years:
    for mm in months:
        data=nc.Dataset('/ihesp/user/xiliangdiao/data/ihespdata/ice500/cmpr_B.E.13.B1850C5.ne120_t12.sehires38.003.sunway_02.cice.h.'+yy+'-'+mm +'.hi.nc')
        plotvar = data.variables['hi'][0,:,:]
        plotvar = plotvar[247:365,700:1300]
        #plotvar = plotvar[224:343,600:1400]
        aveplot = plotvar.mean(axis=0)
        aveplot = aveplot.mean(axis=0)
        resultnew3[i] = aveplot
        
        i = i + 1

# %%
aa = result33

# %%
aa
# Out:
# array([1.02850211, 0.85546762, 0.87030059, 0.80563426, 0.73288924,
#        0.84038228, 0.95539075])

# %%
a = np.hstack((result,aa))

# %%
r = np.hstack((a,result1))

# %%
rnew = np.hstack((r,resultnew3))

# %%
rnew.shape
# Out:
# (349,)

# %%
my_font = {'fontname':'Cambria', 'size':'16'}
##################################################################
fig = plt.figure(figsize=(20,5), dpi=100)
ax0 = fig.add_axes([0.1,0.1,0.7,0.7])
ax0.plot(rnew,'black',linewidth=3)
plt.vlines(noxx, 0,1.6, colors = "grey",linewidth=3)
plt.vlines(mrpxx, 0,1.6, colors = "blue",linewidth=3)
plt.vlines(wspxx, 0,1.6, colors = "yellow",linewidth=3)
plt.hlines(0.6, 0, 350, colors = "black",linestyles = "dashed")
plt.xticks(range(0,350,50), ['150','200','250','300', '350', '400','450','500'],**my_font)
plt.yticks(**my_font)
plt.xlabel('Years',**my_font)
plt.xlabel('Years',**my_font)
plt.ylabel('(m)',color= 'b',**my_font)
plt.axis("tight")
ax0.set(ylim=(0, 1.6),xlim=(0, 350))
ax0.set_title('Sea Ice Thickness (64$^\circ$S - 69$^\circ$S,50$^\circ$W - 20$^\circ$E, September, No running mean )',**my_font)
plt.savefig("seaicethick.png",bbox_inches='tight',dpi=fig.dpi)

# %%
np.savetxt('icethiyear1new.out', rnew)
